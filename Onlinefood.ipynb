# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/sanik/Downloads/onlinefoods.csv")

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# 2                Post Graduate            3   12.9551    77.6593    560017
# 3                     Graduate            6   12.9473    77.5616    560019
# 4                Post Graduate            4   12.9850    77.5533    560010
# ..                         ...          ...       ...        ...       ...
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output   Feedback Unnamed: 12
# 0      Yes   Positive         Yes
# 1      Yes   Positive         Yes
# 2       No  Negative          Yes
# 3       No   Positive         Yes
# 4      Yes   Positive         Yes
# ..     ...        ...         ...
# 383    Yes   Positive         Yes
# 384    Yes   Positive         Yes
# 385    Yes   Positive         Yes
# 386    Yes   Positive         Yes
# 387    Yes   Positive         Yes
#
# [388 rows x 13 columns]

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
df.rename(columns={"Age":"age","Gender":"gender","Marital Status":"relationship","Occupation":"work","Monthly Income":"income",
                  "Educational Qualifications":"degree","Family size":"family_size","Pin code":"pincode","Output":"output","Feedback":"feedback"},inplace=True)

# %%
df.isnull()
# Out:
#        age  gender  relationship   work  income  degree  family_size  \
# 0    False   False         False  False   False   False        False
# 1    False   False         False  False   False   False        False
# 2    False   False         False  False   False   False        False
# 3    False   False         False  False   False   False        False
# 4    False   False         False  False   False   False        False
# ..     ...     ...           ...    ...     ...     ...          ...
# 383  False   False         False  False   False   False        False
# 384  False   False         False  False   False   False        False
# 385  False   False         False  False   False   False        False
# 386  False   False         False  False   False   False        False
# 387  False   False         False  False   False   False        False
#
#      latitude  longitude  pincode  output  feedback  Unnamed: 12
# 0       False      False    False   False     False        False
# 1       False      False    False   False     False        False
# 2       False      False    False   False     False        False
# 3       False      False    False   False     False        False
# 4       False      False    False   False     False        False
# ..        ...        ...      ...     ...       ...          ...
# 383     False      False    False   False     False        False
# 384     False      False    False   False     False        False
# 385     False      False    False   False     False        False
# 386     False      False    False   False     False        False
# 387     False      False    False   False     False        False
#
# [388 rows x 13 columns]

# %%
df.notnull()
# Out:
#       age  gender  relationship  work  income  degree  family_size  latitude  \
# 0    True    True          True  True    True    True         True      True
# 1    True    True          True  True    True    True         True      True
# 2    True    True          True  True    True    True         True      True
# 3    True    True          True  True    True    True         True      True
# 4    True    True          True  True    True    True         True      True
# ..    ...     ...           ...   ...     ...     ...          ...       ...
# 383  True    True          True  True    True    True         True      True
# 384  True    True          True  True    True    True         True      True
# 385  True    True          True  True    True    True         True      True
# 386  True    True          True  True    True    True         True      True
# 387  True    True          True  True    True    True         True      True
#
#      longitude  pincode  output  feedback  Unnamed: 12
# 0         True     True    True      True         True
# 1         True     True    True      True         True
# 2         True     True    True      True         True
# 3         True     True    True      True         True
# 4         True     True    True      True         True
# ..         ...      ...     ...       ...          ...
# 383       True     True    True      True         True
# 384       True     True    True      True         True
# 385       True     True    True      True         True
# 386       True     True    True      True         True
# 387       True     True    True      True         True
#
# [388 rows x 13 columns]

# %%
df.fillna(0)
# Out:
#      age  gender relationship     work          income         degree  \
# 0     20  Female       Single  Student       No Income  Post Graduate
# 1     24  Female       Single  Student  Below Rs.10000       Graduate
# 2     22    Male       Single  Student  Below Rs.10000  Post Graduate
# 3     22  Female       Single  Student       No Income       Graduate
# 4     22    Male       Single  Student  Below Rs.10000  Post Graduate
# ..   ...     ...          ...      ...             ...            ...
# 383   23  Female       Single  Student       No Income  Post Graduate
# 384   23  Female       Single  Student       No Income  Post Graduate
# 385   22  Female       Single  Student       No Income  Post Graduate
# 386   23    Male       Single  Student  Below Rs.10000  Post Graduate
# 387   23    Male       Single  Student       No Income  Post Graduate
#
#      family_size  latitude  longitude  pincode output   feedback Unnamed: 12
# 0              4   12.9766    77.5993   560001    Yes   Positive         Yes
# 1              3   12.9770    77.5773   560009    Yes   Positive         Yes
# 2              3   12.9551    77.6593   560017    Yes  Negative          Yes
# 3              6   12.9473    77.5616   560019    Yes   Positive         Yes
# 4              4   12.9850    77.5533   560010    Yes   Positive         Yes
# ..           ...       ...        ...      ...    ...        ...         ...
# 383            2   12.9766    77.5993   560001    Yes   Positive         Yes
# 384            4   12.9854    77.7081   560048    Yes   Positive         Yes
# 385            5   12.9850    77.5533   560010    Yes   Positive         Yes
# 386            2   12.9770    77.5773   560009    Yes   Positive         Yes
# 387            5   12.8988    77.5764   560078    Yes   Positive         Yes
#
# [388 rows x 13 columns]

# %%
df.dropna()
# Out:
#      age  gender relationship     work          income         degree  \
# 0     20  Female       Single  Student       No Income  Post Graduate
# 1     24  Female       Single  Student  Below Rs.10000       Graduate
# 2     22    Male       Single  Student  Below Rs.10000  Post Graduate
# 3     22  Female       Single  Student       No Income       Graduate
# 4     22    Male       Single  Student  Below Rs.10000  Post Graduate
# ..   ...     ...          ...      ...             ...            ...
# 383   23  Female       Single  Student       No Income  Post Graduate
# 384   23  Female       Single  Student       No Income  Post Graduate
# 385   22  Female       Single  Student       No Income  Post Graduate
# 386   23    Male       Single  Student  Below Rs.10000  Post Graduate
# 387   23    Male       Single  Student       No Income  Post Graduate
#
#      family_size  latitude  longitude  pincode output   feedback Unnamed: 12
# 0              4   12.9766    77.5993   560001    Yes   Positive         Yes
# 1              3   12.9770    77.5773   560009    Yes   Positive         Yes
# 2              3   12.9551    77.6593   560017    Yes  Negative          Yes
# 3              6   12.9473    77.5616   560019    Yes   Positive         Yes
# 4              4   12.9850    77.5533   560010    Yes   Positive         Yes
# ..           ...       ...        ...      ...    ...        ...         ...
# 383            2   12.9766    77.5993   560001    Yes   Positive         Yes
# 384            4   12.9854    77.7081   560048    Yes   Positive         Yes
# 385            5   12.9850    77.5533   560010    Yes   Positive         Yes
# 386            2   12.9770    77.5773   560009    Yes   Positive         Yes
# 387            5   12.8988    77.5764   560078    Yes   Positive         Yes
#
# [388 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           388 non-null    int64
#  1   gender        388 non-null    object
#  2   relationship  388 non-null    object
#  3   work          388 non-null    object
#  4   income        388 non-null    object
#  5   degree        388 non-null    object
#  6   family_size   388 non-null    int64
#  7   latitude      388 non-null    float64
#  8   longitude     388 non-null    float64
#  9   pincode       388 non-null    int64
#  10  output        388 non-null    object
#  11  feedback      388 non-null    object
#  12  Unnamed: 12   388 non-null    object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 39.5+ KB

# %%
missing_values = ["Na" , "na"]

# %%
df=pd.read_csv("C:/Users/sanik/Downloads/onlinefoods.csv",na_values = missing_values)
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# 2                Post Graduate            3   12.9551    77.6593    560017
# 3                     Graduate            6   12.9473    77.5616    560019
# 4                Post Graduate            4   12.9850    77.5533    560010
# ..                         ...          ...       ...        ...       ...
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output   Feedback Unnamed: 12
# 0      Yes   Positive         Yes
# 1      Yes   Positive         Yes
# 2      Yes  Negative          Yes
# 3      Yes   Positive         Yes
# 4      Yes   Positive         Yes
# ..     ...        ...         ...
# 383    Yes   Positive         Yes
# 384    Yes   Positive         Yes
# 385    Yes   Positive         Yes
# 386    Yes   Positive         Yes
# 387    Yes   Positive         Yes
#
# [388 rows x 13 columns]

# %%
df["Monthly Income"].unique()
# Out:
# array(['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000',
#        '25001 to 50000'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
plt.scatter(df['Age'],df['Pin code'])
plt.show()

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
df["Age"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Monthly Income"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Monthly Income'>

# %%
from sklearn.metrics import confusion_matrix


y_true = [0]  
y_pred = [0]  

conf_matrix = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1]]

# %%
from sklearn.metrics import confusion_matrix


conf_matrix = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1]]

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
df["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
work_by_gender.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='gender,work'>

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
df["Marital Status"].value_counts()
# Out:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
degree_by_income = df.groupby("degree").income
degree_by_income.value_counts().plot(kind="bar",ylabel="count",title="Income vs Degree")
# Out:
# <Axes: title={'center': 'Income vs Degree'}, xlabel='degree,income', ylabel='count'>

# %%
degree_by_income = df.groupby("degree").gender
degree_by_income.value_counts().plot(kind="bar",ylabel="count",title="Gender vs Degree")
# Out:
# <Axes: title={'center': 'Gender vs Degree'}, xlabel='degree,gender', ylabel='count'>

# %%
df["output"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["feedback"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age  gender relationship     work          income         degree  \
# 0   20  Female       Single  Student       No Income  Post Graduate
# 1   24  Female       Single  Student  Below Rs.10000       Graduate
# 2   22    Male       Single  Student  Below Rs.10000  Post Graduate
# 3   22  Female       Single  Student       No Income       Graduate
# 4   22    Male       Single  Student  Below Rs.10000  Post Graduate
#
#    family_size  latitude  longitude  pincode output   feedback
# 0            4   12.9766    77.5993   560001    Yes   Positive
# 1            3   12.9770    77.5773   560009    Yes   Positive
# 2            3   12.9551    77.6593   560017    Yes  Negative
# 3            6   12.9473    77.5616   560019    Yes   Positive
# 4            4   12.9850    77.5533   560010    Yes   Positive

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = df.select_dtypes(include=['float64', 'int64']) # Corrected to select_dtypes
corr = df.corr()
plt.figure(figsize=(10, 6)) # Corrected to plt.figure
sns.heatmap(corr, annot=True)
plt.show()

# %%
df.drop(columns=["pincode"],inplace=True)

# %%
df['gender'] = df['gender'].astype('category')
df = pd.get_dummies(df, columns=['gender'], prefix='gender')

# %%
df.head()
# Out:
#    age relationship     work          income         degree  family_size  \
# 0   20       Single  Student       No Income  Post Graduate            4
# 1   24       Single  Student  Below Rs.10000       Graduate            3
# 2   22       Single  Student  Below Rs.10000  Post Graduate            3
# 3   22       Single  Student       No Income       Graduate            6
# 4   22       Single  Student  Below Rs.10000  Post Graduate            4
#
#    latitude  longitude output   feedback  gender_Female  gender_Male
# 0   12.9766    77.5993    Yes   Positive              1            0
# 1   12.9770    77.5773    Yes   Positive              1            0
# 2   12.9551    77.6593    Yes  Negative               0            1
# 3   12.9473    77.5616    Yes   Positive              1            0
# 4   12.9850    77.5533    Yes   Positive              0            1

# %%
print(df.columns)
# Out:
# Index(['Age', 'Family size', 'latitude', 'longitude', 'Pin code'], dtype='object')

# %%
if 'feedback' in df.columns:
    
    df['feedback'] = pd.to_numeric(df['feedback'], errors='coerce')
    
    print("Conversion successful.")
else:
    print("Column 'feedback' does not exist in the DataFrame.")


print(df.head())
# Out:
# Column 'feedback' does not exist in the DataFrame.
#    Age  Family size  latitude  longitude  Pin code
# 0   20            4   12.9766    77.5993    560001
# 1   24            3   12.9770    77.5773    560009
# 2   22            3   12.9551    77.6593    560017
# 3   22            6   12.9473    77.5616    560019
# 4   22            4   12.9850    77.5533    560010

# %%
 
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df['Output']= label_encoder.fit_transform(df['Output']) 

df['Output'].unique()
# Out:
# array([1, 0])

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df['Feedback']= label_encoder.fit_transform(df['Feedback']) 

df['Feedback'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# 2                Post Graduate            3   12.9551    77.6593    560017
# 3                     Graduate            6   12.9473    77.5616    560019
# 4                Post Graduate            4   12.9850    77.5533    560010
# ..                         ...          ...       ...        ...       ...
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#      Output  Feedback Unnamed: 12
# 0         1         1         Yes
# 1         1         1         Yes
# 2         0         0         Yes
# 3         0         1         Yes
# 4         1         1         Yes
# ..      ...       ...         ...
# 383       1         1         Yes
# 384       1         1         Yes
# 385       1         1         Yes
# 386       1         1         Yes
# 387       1         1         Yes
#
# [388 rows x 13 columns]

# %%
from sklearn.metrics import confusion_matrix


y_true = [1]  
y_pred = [1]  

conf_matrix = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X=df[['Age','Feedback']]
Y=df['Occupation']
X_scaled= scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state = 42)
print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
from sklearn.linear_model import LogisticRegression
basemodel= LogisticRegression()
basemodel.fit(X_train,y_train)
print("Training accuracy:", basemodel.score(X_train,y_train)*100)
# Out:
# Training accuracy: 70.64516129032258

# %%
model= LogisticRegression()
model.fit(X_train,y_train)
y_predict= model.predict(X_test)
print("Training accuracy:", model.score(X_train,y_train)*100)
print("Testing accuracy:", model.score(X_test,y_test)*100)
# Out:
# Training accuracy: 70.64516129032258
# Testing accuracy: 74.35897435897436

# %%
y_predict= basemodel.predict(X_test)
print("Testing accuracy:", basemodel.score(X_test,y_test)*100)
# Out:
# Testing accuracy: 74.35897435897436

# %%
from sklearn.metrics import accuracy_score
Acc=accuracy_score(y_test,y_predict)
print(Acc)
# Out:
# 0.7435897435897436

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_predict)
print(cm)
# Out:
# [[14  0  0  5]
#  [ 2  0  0  1]
#  [ 4  0  0  5]
#  [ 3  0  0 44]]
